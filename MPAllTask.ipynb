# %% [markdown]
# <a href="https://colab.research.google.com/github/Nidhii269/MPG-Analyzerr/blob/main/MPAllTask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Read the .csv file directly into a pandas DataFrame
car_data = pd.read_csv('/content/cars.csv',skiprows=[1] ,delimiter=';')# Print the column names
column_names = car_data.columns.tolist()
print("Column Names:")
print(column_names)
# Find the car with the highest MPG
highest_mpg_car = car_data.loc[car_data['MPG'].idxmax()]
print("\nCar with the highest MPG:")
print(highest_mpg_car)

# Find the car with the lowest MPG
lowest_mpg_car = car_data.loc[car_data['MPG'].idxmin()]
print("\nCar with the lowest MPG:")
print(lowest_mpg_car)
# Find the average MPG of all cars
average_mpg = car_data['MPG'].mean()
print("\nAverage MPG of all cars:", average_mpg)
# Find the most common MPG
most_common_mpg = car_data['MPG'].mode().values[0]
print("\nMost common MPG:", most_common_mpg)
import matplotlib.pyplot as plt

#MPG compare with other data and visullize comparision
mpg_by_cylinders = car_data.groupby('Cylinders')['MPG'].mean()
print(mpg_by_cylinders)
# Bar chart of average MPG by number of cylinders
plt.bar(mpg_by_cylinders.index, mpg_by_cylinders.values)
plt.xlabel('Number of Cylinders')
plt.ylabel('Average MPG')
plt.title('Average MPG by Number of Cylinders')
plt.show()
mpg_over_time = car_data.groupby('Model')['MPG'].mean()
plt.plot(mpg_over_time.index, mpg_over_time.values)
plt.xlabel('Model')
plt.ylabel('Average MPG')
plt.title('Average MPG Over Time')
plt.xticks(rotation=45)
plt.show()
# Out:
# Column Names:
# ['Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight', 'Acceleration', 'Model', 'Origin']
#
# Car with the highest MPG:
# Car             Mazda GLC
# MPG                  46.6
# Cylinders               4
# Displacement         86.0
# Horsepower           65.0
# Weight             2110.0
# Acceleration         17.9
# Model                  80
# Origin              Japan
# Name: 329, dtype: object
#
# Car with the lowest MPG:
# Car             Citroen DS-21 Pallas
# MPG                              0.0
# Cylinders                          4
# Displacement                   133.0
# Horsepower                     115.0
# Weight                        3090.0
# Acceleration                    17.5
# Model                             70
# Origin                        Europe
# Name: 10, dtype: object
#
# Average MPG of all cars: 23.051231527093595
#
# Most common MPG: 13.0
# Cylinders
# 3    20.550000
# 4    28.862319
# 5    27.366667
# 6    19.985714
# ...
